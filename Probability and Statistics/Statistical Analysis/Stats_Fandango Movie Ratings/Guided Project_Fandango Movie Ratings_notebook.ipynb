# %% [markdown]
# ### Project : Investigating Movie Ratings on the Fandango website

# %% [markdown]
# #### In this project, we investigate the hypothesis whether movie ratings on the Fandango website are biased. This is based on an earlier investigation by the Data Journalist Walter Hickey in 2015, where he had concluded that the movie ratings were inaccurate and had displayed evidence for the same.

# %% [markdown]
# ### 1 - Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import percentileofscore
import seaborn as sns

pd.options.display.max_rows = 200
pd.options.display.max_columns = 50

# %% [markdown]
# ### 2 - Understanding the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('fandango_score_comparison.csv').head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 0     3.70           4.3             3.30                 3.55       3.90
# 1     4.25           4.0             3.35                 3.75       3.55
# 2     4.00           4.5             3.20                 4.05       3.90
# 3     0.90           4.2             1.10                 2.35       2.70
# 4     0.70           1.4             1.45                 1.70       2.55
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# 0            3.5                 4.5                    3.5
# 1            4.5                 4.0                    3.5
# 2            4.0                 4.5                    3.0
# 3            1.0                 4.0                    1.0
# 4            0.5                 1.5                    1.5
#
#    Metacritic_user_norm_round  IMDB_norm_round  Metacritic_user_vote_count  \
# 0                         3.5              4.0                        1330
# 1                         4.0              3.5                         249
# 2                         4.0              4.0                         627
# 3                         2.5              2.5                          31
# 4                         1.5              2.5                          88
#
#    IMDB_user_vote_count  Fandango_votes  Fandango_Difference
# 0                271107           14846                  0.5
# 1                 65709           12640                  0.5
# 2                103660           12055                  0.5
# 3                  3136            1793                  0.5
# 4                 19560            1021                  0.5

# %%
pd.read_csv('movie_ratings_16_17.csv').head()
# Out:
#                      movie  year  metascore  imdb  tmeter  audience  fandango  \
# 0      10 Cloverfield Lane  2016         76   7.2      90        79       3.5
# 1                 13 Hours  2016         48   7.3      50        83       4.5
# 2      A Cure for Wellness  2016         47   6.6      40        47       3.0
# 3          A Dog's Purpose  2017         43   5.2      33        76       4.5
# 4  A Hologram for the King  2016         58   6.1      70        57       3.0
#
#    n_metascore  n_imdb  n_tmeter  n_audience  nr_metascore  nr_imdb  \
# 0         3.80    3.60      4.50        3.95           4.0      3.5
# 1         2.40    3.65      2.50        4.15           2.5      3.5
# 2         2.35    3.30      2.00        2.35           2.5      3.5
# 3         2.15    2.60      1.65        3.80           2.0      2.5
# 4         2.90    3.05      3.50        2.85           3.0      3.0
#
#    nr_tmeter  nr_audience
# 0        4.5          4.0
# 1        2.5          4.0
# 2        2.0          2.5
# 3        1.5          4.0
# 4        3.5          3.0

# %% [markdown]
# #### Creating the dataframes for analysis

# %%
df_ratings_before = pd.read_csv('fandango_score_comparison.csv')
df_ratings_after = pd.read_csv('movie_ratings_16_17.csv')

# %%
## Isolating only the relevant columns for analysis :

df_ratings_before = df_ratings_before[['FILM','Fandango_Stars', 'Fandango_Ratingvalue','Fandango_votes', 'Fandango_Difference']]

df_ratings_after = df_ratings_after[['movie', 'year', 'fandango']]

# %%
df_ratings_before.columns
# Out:
# Index(['FILM', 'Fandango_Stars', 'Fandango_Ratingvalue', 'Fandango_votes',
#        'Fandango_Difference'],
#       dtype='object')

# %%
df_ratings_before.describe()
# Out:
#        Fandango_Stars  Fandango_Ratingvalue  Fandango_votes  \
# count      146.000000            146.000000      146.000000
# mean         4.089041              3.845205     3848.787671
# std          0.540386              0.502831     6357.778617
# min          3.000000              2.700000       35.000000
# 25%          3.500000              3.500000      222.250000
# 50%          4.000000              3.900000     1446.000000
# 75%          4.500000              4.200000     4439.500000
# max          5.000000              4.800000    34846.000000
#
#        Fandango_Difference
# count           146.000000
# mean              0.243836
# std               0.152665
# min               0.000000
# 25%               0.100000
# 50%               0.200000
# 75%               0.400000
# max               0.500000

# %%
df_ratings_after.describe()
# Out:
#               year    fandango
# count   214.000000  214.000000
# mean   2016.107477    3.894860
# std       0.310444    0.516781
# min    2016.000000    2.500000
# 25%    2016.000000    3.500000
# 50%    2016.000000    4.000000
# 75%    2016.000000    4.500000
# max    2017.000000    5.000000

# %% [markdown]
# #### Sample Representativeness based on Readme file analysis
#
# Readme file for df_ratings_before / fandango_score_comparison.csv - https://github.com/fivethirtyeight/data/blob/master/fandango/README.md
#
# Readme file for df_ratings_after / movie_ratings_16_17.csv -
# https://github.com/mircealex/Movie_ratings_2016_17/blob/master/README.md

# %% [markdown]
# Based on the analysis of two readme files, we can conclude that both the samples are not representative of the Population of Interest:
#
#     a) For the 2015 data, it includes only those movies with 30+ votes (A total of 146).
#     b) For the 2016-17 data, it includes 214 of the most popular movies i.e. with high number of total votes (A total of 214)

# %% [markdown]
# ### 3 - Changing the Goal of our Analysis

# %% [markdown]
# #### Based on the Sample Analysis, we will update the goal of the Project by focusing only on the popular movies rather than all the movies. We will try to conclude whether or not, the ratings have been updated for popular movies. This can be a good proxy for the initial goal as well.

# %%
df_ratings_before
# Out:
#                                                   FILM  Fandango_Stars  \
# 0                       Avengers: Age of Ultron (2015)             5.0
# 1                                    Cinderella (2015)             5.0
# 2                                       Ant-Man (2015)             5.0
# 3                               Do You Believe? (2015)             5.0
# 4                        Hot Tub Time Machine 2 (2015)             3.5
# 5                             The Water Diviner (2015)             4.5
# 6                                Irrational Man (2015)             4.0
# 7                                      Top Five (2014)             4.0
# 8                         Shaun the Sheep Movie (2015)             4.5
# 9                                  Love & Mercy (2015)             4.5
# 10                   Far From The Madding Crowd (2015)             4.5
# 11                                    Black Sea (2015)             4.0
# 12                                    Leviathan (2014)             4.0
# 13                                     Unbroken (2014)             4.5
# 14                           The Imitation Game (2014)             5.0
# 15                                      Taken 3 (2015)             4.5
# 16                                        Ted 2 (2015)             4.5
# 17                                     Southpaw (2015)             5.0
# 18      Night at the Museum: Secret of the Tomb (2014)             4.5
# 19                                       Pixels (2015)             4.5
# 20                               McFarland, USA (2015)             5.0
# 21                         Insidious: Chapter 3 (2015)             4.5
# 22                      The Man From U.N.C.L.E. (2015)             4.5
# 23                                Run All Night (2015)             4.5
# 24                                   Trainwreck (2015)             4.5
# 25                                        Selma (2014)             5.0
# 26                                   Ex Machina (2015)             4.5
# 27                                  Still Alice (2015)             4.5
# 28                                   Wild Tales (2014)             4.5
# 29                          The End of the Tour (2015)             4.5
# 30                                     Red Army (2015)             4.5
# 31                        When Marnie Was There (2015)             4.5
# 32                           The Hunting Ground (2015)             4.5
# 33                            The Boy Next Door (2015)             4.0
# 34                                        Aloha (2015)             3.5
# 35                                     The Loft (2015)             4.0
# 36                                 5 Flights Up (2015)             4.0
# 37                                Welcome to Me (2015)             4.0
# 38                                Saint Laurent (2015)             3.5
# 39                            Maps to the Stars (2015)             3.5
# 40                    I'll See You In My Dreams (2015)             4.0
# 41                                     Timbuktu (2015)             4.0
# 42                                   About Elly (2015)             4.0
# 43                  The Diary of a Teenage Girl (2015)             4.0
# 44                 Kingsman: The Secret Service (2015)             4.5
# 45                                 Tomorrowland (2015)             4.0
# 46              The Divergent Series: Insurgent (2015)             4.5
# 47                                        Annie (2014)             4.5
# 48                               Fantastic Four (2015)             3.0
# 49                           Terminator Genisys (2015)             4.5
# 50                              Pitch Perfect 2 (2015)             4.5
# 51                                    Entourage (2015)             4.5
# 52                           The Age of Adaline (2015)             4.5
# 53                                  Hot Pursuit (2015)             4.0
# 54                                     The DUFF (2015)             4.5
# 55                               Black or White (2015)             4.5
# 56                              Project Almanac (2015)             4.0
# 57                          Ricki and the Flash (2015)             4.0
# 58                                  Seventh Son (2015)             3.5
# 59                                    Mortdecai (2015)             3.5
# 60                          Unfinished Business (2015)             3.5
# 61                               American Ultra (2015)             4.0
# 62                                   True Story (2015)             3.5
# 63                                     Child 44 (2015)             4.0
# 64                                  Dark Places (2015)             4.0
# 65                                      Birdman (2014)             4.0
# 66                                     The Gift (2015)             4.0
# 67                                   Unfriended (2015)             3.0
# 68                               Monkey Kingdom (2015)             4.5
# 69                                   Mr. Turner (2014)             3.5
# 70                     Seymour: An Introduction (2015)             4.5
# 71                            The Wrecking Crew (2015)             4.5
# 72                              American Sniper (2015)             5.0
# 73                                    Furious 7 (2015)             5.0
# 74    The Hobbit: The Battle of the Five Armies (2014)             4.5
# 75                                  San Andreas (2015)             4.5
# 76                       Straight Outta Compton (2015)             5.0
# 77                                     Vacation (2015)             4.0
# 78                                      Chappie (2015)             4.0
# 79                                  Poltergeist (2015)             3.0
# 80                                  Paper Towns (2015)             4.0
# 81                                     Big Eyes (2014)             4.0
# 82                                     Blackhat (2015)             3.0
# 83                                    Self/less (2015)             4.0
# 84                                   Sinister 2 (2015)             3.5
# 85                                   Little Boy (2015)             4.5
# 86               Me and Earl and The Dying Girl (2015)             4.5
# 87                                       Maggie (2015)             3.5
# 88                           Mad Max: Fury Road (2015)             4.5
# 89                                          Spy (2015)             4.5
# 90     The SpongeBob Movie: Sponge Out of Water (2015)             3.5
# 91                                   Paddington (2015)             4.5
# 92                                         Dope (2015)             4.5
# 93                    What We Do in the Shadows (2015)             4.5
# 94                                The Overnight (2015)             3.5
# 95                        The Salt of the Earth (2015)             4.5
# 96                              Song of the Sea (2014)             4.5
# 97                         Fifty Shades of Grey (2015)             4.0
# 98                                     Get Hard (2015)             4.0
# 99                                        Focus (2015)             4.0
# 100                           Jupiter Ascending (2015)             3.5
# 101                                 The Gallows (2015)             3.0
# 102       The Second Best Exotic Marigold Hotel (2015)             4.0
# 103                               Strange Magic (2015)             3.5
# 104                                  The Gunman (2015)             3.5
# 105                            Hitman: Agent 47 (2015)             4.0
# 106                                        Cake (2015)             3.5
# 107                           The Vatican Tapes (2015)             3.0
# 108                              A Little Chaos (2015)             4.0
# 109  The 100-Year-Old Man Who Climbed Out the Windo...             4.0
# 110                      Escobar: Paradise Lost (2015)             4.0
# 111                              Into the Woods (2014)             3.5
# 112                                  It Follows (2015)             3.0
# 113                               Inherent Vice (2014)             3.0
# 114                         A Most Violent Year (2014)             3.5
# 115                           While We're Young (2015)             3.0
# 116                        Clouds of Sils Maria (2015)             3.5
# 117                          Testament of Youth (2015)             4.0
# 118                       Infinitely Polar Bear (2015)             4.0
# 119                                     Phoenix (2015)             3.5
# 120                                The Wolfpack (2015)             3.5
# 121              The Stanford Prison Experiment (2015)             4.0
# 122                                   Tangerine (2015)             4.0
# 123                              Magic Mike XXL (2015)             4.5
# 124                                        Home (2015)             4.5
# 125                          The Wedding Ringer (2015)             4.5
# 126                               Woman in Gold (2015)             4.5
# 127                         The Last Five Years (2015)             4.5
# 128        Mission: Impossible â€“ Rogue Nation (2015)             4.5
# 129                                         Amy (2015)             4.5
# 130                              Jurassic World (2015)             4.5
# 131                                     Minions (2015)             4.0
# 132                                         Max (2015)             4.5
# 133                      Paul Blart: Mall Cop 2 (2015)             3.5
# 134                            The Longest Ride (2015)             4.5
# 135                          The Lazarus Effect (2015)             3.0
# 136         The Woman In Black 2 Angel of Death (2015)             3.0
# 137                               Danny Collins (2015)             4.0
# 138                                 Spare Parts (2015)             4.5
# 139                                      Serena (2015)             3.0
# 140                                  Inside Out (2015)             4.5
# 141                                  Mr. Holmes (2015)             4.0
# 142                                         '71 (2015)             3.5
# 143                         Two Days, One Night (2014)             3.5
# 144          Gett: The Trial of Viviane Amsalem (2015)             3.5
# 145                 Kumiko, The Treasure Hunter (2015)             3.5
#
#      Fandango_Ratingvalue  Fandango_votes  Fandango_Difference
# 0                     4.5           14846                  0.5
# 1                     4.5           12640                  0.5
# 2                     4.5           12055                  0.5
# 3                     4.5            1793                  0.5
# 4                     3.0            1021                  0.5
# 5                     4.0             397                  0.5
# 6                     3.5             252                  0.5
# 7                     3.5            3223                  0.5
# 8                     4.0             896                  0.5
# 9                     4.0             864                  0.5
# 10                    4.0             804                  0.5
# 11                    3.5             218                  0.5
# 12                    3.5              64                  0.5
# 13                    4.1            9443                  0.4
# 14                    4.6            8055                  0.4
# 15                    4.1            6757                  0.4
# 16                    4.1            6437                  0.4
# 17                    4.6            5597                  0.4
# 18                    4.1            5445                  0.4
# 19                    4.1            3886                  0.4
# 20                    4.6            3364                  0.4
# 21                    4.1            3276                  0.4
# 22                    4.1            2686                  0.4
# 23                    4.1            2066                  0.4
# 24                    4.1            8381                  0.4
# 25                    4.6            7025                  0.4
# 26                    4.1            3458                  0.4
# 27                    4.1            1258                  0.4
# 28                    4.1             235                  0.4
# 29                    4.1             121                  0.4
# 30                    4.1              54                  0.4
# 31                    4.1              46                  0.4
# 32                    4.1              42                  0.4
# 33                    3.6            2800                  0.4
# 34                    3.1            2284                  0.4
# 35                    3.6             811                  0.4
# 36                    3.6              79                  0.4
# 37                    3.6              56                  0.4
# 38                    3.1              43                  0.4
# 39                    3.1              35                  0.4
# 40                    3.6             281                  0.4
# 41                    3.6              74                  0.4
# 42                    3.6              43                  0.4
# 43                    3.6              38                  0.4
# 44                    4.2           15205                  0.3
# 45                    3.7            8077                  0.3
# 46                    4.2            7123                  0.3
# 47                    4.2            6835                  0.3
# 48                    2.7            6288                  0.3
# 49                    4.2            6272                  0.3
# 50                    4.2            4577                  0.3
# 51                    4.2            4279                  0.3
# 52                    4.2            3325                  0.3
# 53                    3.7            2618                  0.3
# 54                    4.2            2273                  0.3
# 55                    4.2            1862                  0.3
# 56                    3.7            1834                  0.3
# 57                    3.7            1462                  0.3
# 58                    3.2            1213                  0.3
# 59                    3.2            1196                  0.3
# 60                    3.2             821                  0.3
# 61                    3.7             638                  0.3
# 62                    3.2             540                  0.3
# 63                    3.7             308                  0.3
# 64                    3.7              55                  0.3
# 65                    3.7            4194                  0.3
# 66                    3.7            2680                  0.3
# 67                    2.7            2507                  0.3
# 68                    4.2             701                  0.3
# 69                    3.2             290                  0.3
# 70                    4.2              41                  0.3
# 71                    4.2              38                  0.3
# 72                    4.8           34085                  0.2
# 73                    4.8           33538                  0.2
# 74                    4.3           15337                  0.2
# 75                    4.3            9749                  0.2
# 76                    4.8            8096                  0.2
# 77                    3.8            3815                  0.2
# 78                    3.8            3642                  0.2
# 79                    2.8            2704                  0.2
# 80                    3.8            1750                  0.2
# 81                    3.8            1501                  0.2
# 82                    2.8            1430                  0.2
# 83                    3.8            1415                  0.2
# 84                    3.3             973                  0.2
# 85                    4.3             811                  0.2
# 86                    4.3             624                  0.2
# 87                    3.3              95                  0.2
# 88                    4.3           10509                  0.2
# 89                    4.3            9418                  0.2
# 90                    3.3            4493                  0.2
# 91                    4.3            4045                  0.2
# 92                    4.3            2195                  0.2
# 93                    4.3             259                  0.2
# 94                    3.3             110                  0.2
# 95                    4.3              83                  0.2
# 96                    4.3              66                  0.2
# 97                    3.9           34846                  0.1
# 98                    3.9            5933                  0.1
# 99                    3.9            4933                  0.1
# 100                   3.4            4122                  0.1
# 101                   2.9            1896                  0.1
# 102                   3.9            1870                  0.1
# 103                   3.4            1117                  0.1
# 104                   3.4             996                  0.1
# 105                   3.9             917                  0.1
# 106                   3.4             482                  0.1
# 107                   2.9             210                  0.1
# 108                   3.9              83                  0.1
# 109                   3.9              63                  0.1
# 110                   3.9              48                  0.1
# 111                   3.4           13055                  0.1
# 112                   2.9            2097                  0.1
# 113                   2.9            1078                  0.1
# 114                   3.4             675                  0.1
# 115                   2.9             449                  0.1
# 116                   3.4             162                  0.1
# 117                   3.9             127                  0.1
# 118                   3.9             124                  0.1
# 119                   3.4              70                  0.1
# 120                   3.4              66                  0.1
# 121                   3.9              51                  0.1
# 122                   3.9              36                  0.1
# 123                   4.4            9363                  0.1
# 124                   4.4            7705                  0.1
# 125                   4.4            6506                  0.1
# 126                   4.4            2435                  0.1
# 127                   4.4              99                  0.1
# 128                   4.4            8357                  0.1
# 129                   4.4             729                  0.1
# 130                   4.5           34390                  0.0
# 131                   4.0           14998                  0.0
# 132                   4.5            3412                  0.0
# 133                   3.5            3054                  0.0
# 134                   4.5            2603                  0.0
# 135                   3.0            1651                  0.0
# 136                   3.0            1333                  0.0
# 137                   4.0             531                  0.0
# 138                   4.5             450                  0.0
# 139                   3.0              50                  0.0
# 140                   4.5           15749                  0.0
# 141                   4.0            1348                  0.0
# 142                   3.5             192                  0.0
# 143                   3.5             118                  0.0
# 144                   3.5              59                  0.0
# 145                   3.5              41                  0.0

# %%
df_ratings_after
# Out:
#                           movie  year  fandango
# 0           10 Cloverfield Lane  2016       3.5
# 1                      13 Hours  2016       4.5
# 2           A Cure for Wellness  2016       3.0
# 3               A Dog's Purpose  2017       4.5
# 4       A Hologram for the King  2016       3.0
# ..                          ...   ...       ...
# 209           X-Men: Apocalypse  2016       4.0
# 210                          XX  2017       3.0
# 211  xXx: Return of Xander Cage  2017       4.0
# 212                 Zoolander 2  2016       2.5
# 213                    Zootopia  2016       4.5
#
# [214 rows x 3 columns]

# %% [markdown]
# ### Updated populations of interest post the goal modification and Isolating the Samples required
#
#
# Currently we have two populations of interest.
#
#     1. Popular movies released in 2015
#     2. Popular movies released in 2016
#
# We will consider 30 votes as the benchmark for popularity. Since the 2016 data doesn't have a 'Votes' column, we can do a random sampling and check for the ratings directly on the Fandango Website.

# %%
df_ratings_after.sample(10, random_state = 1)
# Out:
#                                        movie  year  fandango
# 108                   Mechanic: Resurrection  2016       4.0
# 206                                 Warcraft  2016       4.0
# 106                                Max Steel  2016       3.5
# 107                            Me Before You  2016       4.5
# 51   Fantastic Beasts and Where to Find Them  2016       4.5
# 33                                      Cell  2016       3.0
# 59                                    Genius  2016       3.5
# 152                                    Sully  2016       4.5
# 4                    A Hologram for the King  2016       3.0
# 31                Captain America: Civil War  2016       4.5

# %% [markdown]
# #### Upon checking the Fandango website, all of the above movies have more than 30 votes. Thus we can consider the 2016 data as consisting of all popular movies. Now we can filter the earlier data set to include only 2015 release movies before we begin the analysis.

# %% [markdown]
# ### 4 · Isolating the Samples We Need

# %%
df_ratings_before['FILM'][-5:-1]
# Out:
# 141                            Mr. Holmes (2015)
# 142                                   '71 (2015)
# 143                   Two Days, One Night (2014)
# 144    Gett: The Trial of Viviane Amsalem (2015)
# Name: FILM, dtype: object

# %%
df_ratings_before['Year'] = df_ratings_before['FILM'].str[-5:-1]

# %%
df_ratings_before['Year'].value_counts()
# Out:
# 2015    129
# 2014     17
# Name: Year, dtype: int64

# %% [markdown]
# #### We will filter out only those movies that were released in 2015 and 2016

# %%
df_ratings_before['Year'] = df_ratings_before['Year'].astype(int)

# %%
fandango_2015 = df_ratings_before[df_ratings_before['Year']== 2015].copy()

# %%
df_ratings_after['year'].value_counts()
# Out:
# 2016    191
# 2017     23
# Name: year, dtype: int64

# %%
fandango_2016 = df_ratings_after[df_ratings_after['year']== 2016].copy()

# %% [markdown]
# #### Thus the samples have been isolated into two separate dataframes, fandango_2015 and fandango_2016

# %% [markdown]
# ### 5  · Comparing Distribution Shapes for 2015 and 2016

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')
from numpy import arange

plt.figure(figsize = (8, 5.5))
fandango_2015['Fandango_Stars'].plot.kde(label = '2015')
fandango_2016['fandango'].plot.kde(label = '2016')
plt.title('Ratings comparision between 2015 and 2016', y = 1.1)
plt.xlabel('Ratings')
plt.ylabel('Proportional Frequencies')
plt.xticks(arange(0,5.1,.5))
plt.xlim([0,5])
plt.legend()

# %% [markdown]
# #### Observations from the KDE plots for 2015 and 2016 ratings.
#
#
# We can make the following observations :
#
# 1. Both the plots are left-skewed, indicating a pattern of high ratings for most movies.
# 2. The 2016 ratings plot is shifted left, in comparision to the 2015 plot, suggesting that the 2016 ratings are slightly lower in comparision to 2015.

# %% [markdown]
# ### 6  · Comparing Relative Frequencies

# %% [markdown]
# #### Comparing Frequency Tables for Granular Analysis

# %%
fandango_2015['Fandango_Stars'].value_counts().sort_index()
# Out:
# 3.0    11
# 3.5    23
# 4.0    37
# 4.5    49
# 5.0     9
# Name: Fandango_Stars, dtype: int64

# %%
fandango_2016['fandango'].value_counts().sort_index()
# Out:
# 2.5     6
# 3.0    14
# 3.5    46
# 4.0    77
# 4.5    47
# 5.0     1
# Name: fandango, dtype: int64

# %% [markdown]
# #### Comparing Proportional Frequency Tables for details

# %%
fandango_2015['Fandango_Stars'].value_counts(normalize = True).sort_index()*100
# Out:
# 3.0     8.527132
# 3.5    17.829457
# 4.0    28.682171
# 4.5    37.984496
# 5.0     6.976744
# Name: Fandango_Stars, dtype: float64

# %%
fandango_2016['fandango'].value_counts(normalize = True).sort_index()*100
# Out:
# 2.5     3.141361
# 3.0     7.329843
# 3.5    24.083770
# 4.0    40.314136
# 4.5    24.607330
# 5.0     0.523560
# Name: fandango, dtype: float64

# %% [markdown]
# #### Observations from the comparision of Frequency Tables:
#
# 1. In 2015, the lowest rating was 3, with about 8.5% movies whereas in 2016, the lowest rating was 2.5 which was given to 3.1% of the movies.
# 2. Movies rated as 5 got reduced from about 7% to 0.5%. Similarly 4.5 rated movies reduced from 37% to 24%.
# 3. Ratings 3.5 and 4 saw the highest increase in proportions, i.e. 6% and 12%.
#
# The shift (lowering) in overall ratings as displayed by the KDE plots can be attributed to the above changes.

# %% [markdown]
# ### 7  · Determining the Direction of the Change

# %%
mean_2015 = fandango_2015['Fandango_Stars'].mean()
median_2015 = fandango_2015['Fandango_Stars'].median()
mode_2015 = fandango_2015['Fandango_Stars'].mode()[0]

# %%
mean_2016 = fandango_2016['fandango'].mean()
median_2016 = fandango_2016['fandango'].median()
mode_2016 = fandango_2016['fandango'].mode()[0]

# %%
diff_mean = mean_2016 - mean_2015
diff_mode = mode_2016 - mode_2016
diff_median = median_2016 - median_2016

# %%
summary = pd.DataFrame()
summary['2015'] = [mean_2015, median_2015, mode_2015 ]
summary['2016'] = [mean_2016, median_2016, mode_2016 ]
summary.index = ['Mean', 'Median', 'Mode']
summary
# Out:
#             2015      2016
# Mean    4.085271  3.887435
# Median  4.000000  4.000000
# Mode    4.500000  4.000000

# %%
plt.figure(figsize = (8,5.5))

summary['2015'].plot.bar(align = 'center', color = '#0002ff', width = 0.25)
summary['2016'].plot.bar(align = 'edge', color ='#eb0202', width = 0.25)

plt.title('Comparision of Rating Stats between 2015 and 2016', y = 1.1)
plt.xticks(rotation = 0)
plt.yticks(arange(0,5.1,.5))
plt.ylabel('Stars')
plt.ylim(0, 5.5)
plt.legend(loc = 'upper center')
plt.show()

# %% [markdown]
# #### Based on the observation of Summary Statistics, we can conclude :
#
# 1. The Mean ratings dropped from about 4 to 3.8 i.e. about a 5% drop.
# 2. The Mode is also slightly lower by 11.11%, though the Median is the same.

# %% [markdown]
# ### Conclusion
#
# #### We can conclude that the 2016 ratings were lower than 2015. This can be most likely attributed to the public exposure caused by the Data Journalist's article. Since Fandango used to sell movie tickets, the ratings inflation could have been a way to increase their sales.
